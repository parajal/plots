# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
plt.rcParams.update({
     "font.size": 22,
     "text.usetex": True,
     "font.family": "sans-serif",
     "font.sans-serif": ["Helvetica"]})
x= [2.1,2.5,2.8,3.0,3.5,4.0,4.5,5.0,5.5,6.0] #dist/bw particles
# x  = np.divide(x, 2)
fig = plt.figure(figsize=(13,6))
ax = fig.add_subplot(111)
dipole = [-0.22955521791610742,-0.11428896853898877, -7.2632705668768380E-002, -5.5116207821657395E-002, -2.9750356241927522E-002, -1.7439112631071285E-002, -1.0887152162302694E-002,
-7.1430605336867984E-003, -4.8788064569952857E-003, -3.4447629888535872E-003]

#(n,nc) = (5,10)
les1 = [-0.29024513878853253,-9.2302040963111731E-002, -0.14684852487989467, 2.8841292639381066E-002,-0.12362855976721901, 5.2721295276270230E-002, -2.4882738660450716E-002,
-5.7604727227697244E-002, 1.6746098534625969E-002, -7.4266772673460962E-002]
ratio1 = [1.2643804894672648,0.80761986168090771, 2.0217961526805497, -0.52328151335636974, 4.1555320804188502, -3.0231638725892878, 2.2855139975546992,
8.0644321794603790, -3.4324170639348139, 21.559327278471734]

#(n,nc) = (10,20)

les2 = [-0.29579433712925557, -0.12314799386604011, -7.2169985332694378E-002, -5.9560505915034062E-002, -7.2150066155893394E-003, -3.2655557059753849E-002, -3.0198939173679482E-003,
-2.1014720678955920E-002, -5.5074221998858211E-003, -8.7465478272287997E-003 ]
ratio2 = [1.2885541867201455,1.0775142644150222, 0.99362931159161028, 1.0806350485461069, 0.24251832673590465, 1.8725469437918194, 0.27738143752821615,
2.9419771230903238, 1.1288462144238616, 2.5390855206963425]

#(n,nc) = (15,40)
les3 = [-0.29904238740560685, -0.12817838421092334, -7.5920510790517606E-002, -5.9681827394922261E-002, -3.0631744388289590E-002, -1.7805500925927042E-002, -9.5818399567491296E-003,
 -7.5893330506249558E-003, -3.7142206923521659E-003, -4.0382920950621654E-003]
ratio3 = [1.3027035068960793, 1.1215289266277375, 1.0452661799044471, 1.0828362427988170, 1.0296261375559570, 1.0210095721386054, 0.88010526663958333,
1.0624763733743441, 0.76129699447836796, 1.1722989674845827]

#(n,nc) = (20,80)
les4 = [-0.30242234174594462, -0.12697210502170939, -7.7394849834564114E-002, -5.7656243060831960E-002, -3.0109538125483299E-002, -1.7592270693672682E-002, -1.0857890389910883E-002,
-6.9233972732354425E-003, -4.5803730306824960E-003, -3.2675096365654770E-003 ]
ratio4 = [1.3174274341978451, 1.1109742842625607, 1.0655647359126734, 1.0460850871198086, 1.0120731960530132, 1.0087824458641614, 0.99731226569119413,
0.96924801919073478, 0.93883064865487897, 0.94854410800927125]

#(n,nc) = (25,100)
les5 = [-0.30288682873817202, -0.12735631752509990, -7.7200477719076052E-002, -5.7630249408293151E-002, -3.0335148385789323E-002, -1.7660988950089707E-002, -1.0934767583592058E-002,
-7.1259076719349399E-003, -4.7861428379518756E-003, -3.5291919191539939E-003]
ratio5 = [1.3194508558235611, 1.1143360479419613, 1.0628886396045658, 1.0456134717172594, 1.0196566434064291, 1.0127229133564459, 1.0043735423717355,
0.99759866773199457, 0.98100690817309466, 1.0245093582849090]

plt.xlabel('$r/a$', fontsize = 28)
plt.ylabel('magnetic force', fontsize = 28)

ax.plot(x,dipole,'cyan',label = 'Dipole')
ax.plot(x,les1, 'blue', label = 'M1')
ax.plot(x,les2, 'green', label = 'M2')
ax.plot(x,les3, 'yellow', label = 'M3')
ax.plot(x,les4, 'purple', label = 'M4')
ax.plot(x,les5, 'red',label = 'M5')

plt.legend() #for legend
plt.grid()
plt.show()

plt.xlabel('r/D')
plt.ylabel('LES/Dipole')
#plt.plot(x,ratio1,'yellow', label = 'LES1')
plt.plot(x,ratio2,'black', label = 'M1')
plt.plot(x,ratio3,'green', label = 'M2')
plt.plot(x,ratio4,'purple', label = 'M3')
plt.plot(x,ratio5,'blue', label = 'M4')

plt.legend() #for legend
plt.grid()
plt.show()
